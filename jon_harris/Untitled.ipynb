# %%
# Setup Packages
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %matplotlib inline

# Used for auto-formatting code
# terminal - pip install nb_black
# %load_ext nb_black

# Display all rows and columns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
house_data = pd.read_csv("jon_HouseData.csv")

# %%
# Separate predictors by numerical and categorical features
from functions_file import categorize

cat_features, num_cont_features, num_disc_features = categorize(house_data)

# %%
# Plot sales price as a function of CONTINUOUS numerical variable data
ncol = 4  # number of columns

plt.figure(figsize=(15, 20))
for idx, col in enumerate(num_cont_features):
    plt.subplot(math.ceil(len(num_cont_features) / ncol), ncol, idx + 1)
    plt.scatter(x=house_data[col], y=house_data["SalePrice_log"])
    plt.ylabel("SalePrice_log")
    plt.xlabel(col)

# %%
# Plot sales price as a function of DISCREET numerical variable data
ncol = 4  # number of columns

plt.figure(figsize=(15, 20))
for idx, col in enumerate(num_disc_features):
    plt.subplot(math.ceil(len(num_disc_features) / ncol), ncol, idx + 1)
    plt.scatter(x=house_data[col], y=house_data["SalePrice_log"])
    plt.ylabel("SalePrice_log")
    plt.xlabel(col)

# %%
house_data[cat_features].head(10)
# Out:
#   MSZoning Street Alley LandContour Utilities LotConfig Condition1 Condition2  \
# 0       RL   Pave   NaN         Lvl    AllPub    Inside       Norm       Norm
# 1       RL   Pave   NaN         Lvl    AllPub       FR2      Feedr       Norm
# 2       RL   Pave   NaN         Lvl    AllPub    Inside       Norm       Norm
# 3       RL   Pave   NaN         Lvl    AllPub    Corner       Norm       Norm
# 4       RL   Pave   NaN         Lvl    AllPub       FR2       Norm       Norm
# 5       RL   Pave   NaN         Lvl    AllPub    Inside       Norm       Norm
# 6       RL   Pave   NaN         Lvl    AllPub    Inside       Norm       Norm
# 7       RL   Pave   NaN         Lvl    AllPub    Corner       PosN       Norm
# 8       RM   Pave   NaN         Lvl    AllPub    Inside     Artery       Norm
# 9       RL   Pave   NaN         Lvl    AllPub    Corner     Artery     Artery
#
#   BldgType HouseStyle RoofStyle RoofMatl Exterior1st Exterior2nd ExterQual  \
# 0     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd        Gd
# 1     1Fam     1Story     Gable  CompShg     MetalSd     MetalSd        TA
# 2     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd        Gd
# 3     1Fam     2Story     Gable  CompShg     Wd Sdng     Wd Shng        TA
# 4     1Fam     2Story     Gable  CompShg     VinylSd     VinylSd        Gd
# 5     1Fam     1.5Fin     Gable  CompShg     VinylSd     VinylSd        TA
# 6     1Fam     1Story     Gable  CompShg     VinylSd     VinylSd        Gd
# 7     1Fam     2Story     Gable  CompShg     HdBoard     HdBoard        TA
# 8     1Fam     1.5Fin     Gable  CompShg     BrkFace     Wd Shng        TA
# 9   2fmCon     1.5Unf     Gable  CompShg     MetalSd     MetalSd        TA
#
#   ExterCond
# 0        TA
# 1        TA
# 2        TA
# 3        TA
# 4        TA
# 5        TA
# 6        TA
# 7        TA
# 8        TA
# 9        TA

# %%
# Plot sales price as a function of DISCREET numerical variable data
ncol = 4  # number of columns

plt.figure(figsize=(15, 20))
for idx, col in enumerate(cat_features):
    plt.subplot(math.ceil(len(cat_features) / ncol), ncol, idx + 1)
    plt.bar(x=house_data[col], height=house_data["SalePrice_log"])
    plt.ylabel("SalePrice_log")
    plt.xlabel(col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2401                 try:
# -> 2402                     left = x - width / 2
#    2403                 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-bae709ad86a8> in <module>
#       5 for idx, col in enumerate(cat_features):
#       6     plt.subplot(math.ceil(len(cat_features) / ncol), ncol, idx + 1)
# ----> 7     plt.bar(x=house_data[col], height=house_data["SalePrice_log"])
#       8     plt.ylabel("SalePrice_log")
#       9     plt.xlabel(col)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2404                     raise TypeError(f'the dtypes of parameters x ({x.dtype}) '
#    2405                                     f'and width ({width.dtype}) '
# -> 2406                                     f'are incompatible') from e
#    2407                 bottom = y
#    2408             elif orientation == 'horizontal':
#
# TypeError: the dtypes of parameters x (object) and width (float64) are incompatible
